# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Seed set for sanity checks
np.random.seed(1186)

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
print(cities)
# Out:
# ['clifton', 'vicuna', 'pevek', 'cape town', 'puerto ayora', 'wanning', 'oranjemund', 'tabukiniberu', 'kaduqli', 'tondi', 'paso de carrasco', 'nome', 'mataura', 'hithadhoo', 'beringovskiy', 'port elizabeth', 'callaway', 'isangel', 'stornoway', 'mar del plata', 'albany', 'busselton', 'hilo', 'bengkulu', 'bontang', 'vanavara', 'khasan', 'nikolskoye', 'sacalaz', 'la ronge', 'victoria', 'lebu', 'bambous virieux', 'atuona', 'hermanus', 'pak chong', 'taolanaro', 'faridpur', 'cherskiy', 'gusau', 'husavik', 'port hardy', 'hobart', 'butaritari', 'kavieng', 'tiksi', 'ndiekro', 'kavaratti', 'ushuaia', 'herat', 'zhangjiakou', 'barrow', 'itarema', 'falealupo', 'kununurra', 'bluff', 'vardo', 'tasiilaq', 'thabazimbi', 'salym', 'mys shmidta', 'bredasdorp', 'buala', 'ixtapa', 'mahebourg', 'sao joao da barra', 'cayenne', 'hambantota', 'moirang', 'erenhot', 'thilogne', 'amderma', 'tiarei', 'kamaishi', 'syracuse', 'kapoeta', 'barentsburg', 'ponta do sol', 'hasaki', 'loa janan', 'nador', 'belushya guba', 'bethel', 'bonavista', 'shakawe', 'thompson', 'porto santo', 'east london', 'avarua', 'belaya gora', 'rikitea', 'sitka', 'new norfolk', 'jamestown', 'santa eulalia del rio', 'new glasgow', 'vaini', 'khatanga', 'punta arenas', 'arraial do cabo', 'codrington', 'alofi', 'cidreira', 'sulangan', 'hualmay', 'sola', 'santa isabel', 'kapaa', 'acarau', 'zapolyarnyy', 'filadelfia', 'banmo', 'buin', 'dunedin', 'kalabo', 'mocuba', 'puerto escondido', 'tuktoyaktuk', 'teknaf', 'norman wells', 'tumannyy', 'hami', 'te anau', 'alice springs', 'shingu', 'rantepao', 'tura', 'tigil', 'simoes', 'suraabad', 'bocanda', 'svetlogorsk', 'khonuu', 'manaure', 'dingle', 'tayzhina', 'banjar', 'ust-tsilma', 'tilichiki', 'castro', 'qaanaaq', 'ponta delgada', 'georgetown', 'saint-philippe', 'salina', 'paracuru', 'saleaula', 'beloha', 'pervomayskoye', 'motygino', 'kodiak', 'vao', 'fortuna', 'doha', 'wagar', 'santa cruz', 'corning', 'nhulunbuy', 'chardara', 'guerrero negro', 'henties bay', 'kathu', 'dikson', 'doaba', 'surab', 'ribeira grande', 'airai', 'brae', 'yeniseysk', 'kruisfontein', 'kapit', 'bajah', 'raduzhnyy', 'sorong', 'atambua', 'priargunsk', 'macheng', 'geraldton', 'faanui', 'nortelandia', 'rio grande', 'mercedes', 'carnarvon', 'micheweni', 'rochester', 'lorengau', 'patawag', 'namibe', 'kutum', 'fort-shevchenko', 'halifax', 'rawson', 'sao manuel', 'panguna', 'lazaro cardenas', 'jinji', 'carayao', 'chhagalnaiya', 'anadyr', 'conde', 'nanortalik', 'necochea', 'longyearbyen', 'ancud', 'teguise', 'port blair', 'san cristobal', 'abha', 'phan rang', 'iqaluit', 'urucara', 'buckingham', 'port alfred', 'korla', 'rundu', 'souillac', 'las margaritas', 'walvis bay', 'ulladulla', 'yanan', 'turan', 'dali', 'santa catarina de tepehuanes', 'lavrentiya', 'saldanha', 'vichy', 'yumen', 'ilulissat', 'torbay', 'tatawin', 'coihaique', 'taburi', 'bathsheba', 'gat', 'camargo', 'okha', 'klaksvik', 'horasan', 'rasht', 'yellowknife', 'hilton head island', 'ngukurr', 'nuuk', 'sechura', 'marcona', 'saskylakh', 'katsuura', 'west milford', 'tadine', 'pyay', 'benicarlo', 'sao filipe', 'lasa', 'esperance', 'jacksonville beach', 'sindor', 'kaitangata', 'nizhneyansk', 'srednekolymsk', 'grindavik', 'westport', 'armenia', 'siukh', 'neiafu', 'avera', 'volkhov', 'attawapiskat', 'marsh harbour', 'kingisepp', 'kiunga', 'samusu', 'polyarnyye zori', 'chicama', 'rimouski', 'koungou', 'tecoanapa', 'illoqqortoormiut', 'huarmey', 'gueret', 'noyabrsk', 'nouadhibou', 'zlocieniec', 'omsukchan', 'richards bay', 'suaza', 'ballina', 'hereford', 'bayan', 'tsaratanana', 'vaitupu', 'san patricio', 'belyy yar', 'opuwo', 'khandyga', 'yar-sale', 'tautira', 'bandarbeyla', 'salalah', 'lagoa', 'ambodifototra', 'caravelas', 'pucallpa', 'grand centre', 'hamilton', 'maraba', 'urdzhar', 'san isidro', 'mahaicony', 'ayan', 'tuatapere', 'vila velha', 'yar', 'mayumba', 'ketchikan', 'wenling', 'chuy', 'umzimvubu', 'chokurdakh', 'lahaina', 'parabel', 'darhan', 'broome', 'raga', 'sokyryany', 'donskoy', 'jasper', 'ulaangom', 'palmer', 'shizuish ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Call API weather check
base_url = f'http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=imperial&q='
count = 1
count2 = 1

# Empty lists to populate
clouds = []
countries = []
humidity = []
lat = []
long = []
temp = []
wind = []
date = []
city_list = []

print(f'Beginning Data Retrieval')
print(f'--------------------------------------------')

for city in cities:
    try:
        response = requests.get(base_url + city).json()
        clouds.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        long.append(response['coord']['lon'])
        temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        date.append(response['dt'])
        city_list.append(city)
        print(f"Processing record {count} of Set {count2} | {city}")
        count=count+1
        if count>=51:
            count=1
            count2=count2+1
    except:
        print("No such city, skipping this one...")
    
    
print("----------------------API Pull Complete----------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------------------
# Processing record 1 of Set 1 | clifton
# Processing record 2 of Set 1 | vicuna
# Processing record 3 of Set 1 | pevek
# Processing record 4 of Set 1 | cape town
# Processing record 5 of Set 1 | puerto ayora
# Processing record 6 of Set 1 | wanning
# Processing record 7 of Set 1 | oranjemund
# No such city, skipping this one...
# Processing record 8 of Set 1 | kaduqli
# Processing record 9 of Set 1 | tondi
# Processing record 10 of Set 1 | paso de carrasco
# Processing record 11 of Set 1 | nome
# Processing record 12 of Set 1 | mataura
# Processing record 13 of Set 1 | hithadhoo
# Processing record 14 of Set 1 | beringovskiy
# Processing record 15 of Set 1 | port elizabeth
# Processing record 16 of Set 1 | callaway
# Processing record 17 of Set 1 | isangel
# Processing record 18 of Set 1 | stornoway
# Processing record 19 of Set 1 | mar del plata
# Processing record 20 of Set 1 | albany
# Processing record 21 of Set 1 | busselton
# Processing record 22 of Set 1 | hilo
# Processing record 23 of Set 1 | bengkulu
# Processing record 24 of Set 1 | bontang
# Processing record 25 of Set 1 | vanavara
# Processing record 26 of Set 1 | khasan
# Processing record 27 of Set 1 | nikolskoye
# Processing record 28 of Set 1 | sacalaz
# Processing record 29 of Set 1 | la ronge
# Processing record 30 of Set 1 | victoria
# Processing record 31 of Set 1 | lebu
# No such city, skipping this one...
# Processing record 32 of Set 1 | atuona
# Processing record 33 of Set 1 | hermanus
# Processing record 34 of Set 1 | pak chong
# No such city, skipping this one...
# Processing record 35 of Set 1 | faridpur
# Processing record 36 of Set 1 | cherskiy
# Processing record 37 of Set 1 | gusau
# Processing record 38 of Set 1 | husavik
# Processing record 39 of Set 1 | port hardy
# Processing record 40 of Set 1 | hobart
# Processing record 41 of Set 1 | butaritari
# Processing record 42 of Set 1 | kavieng
# Processing record 43 of Set 1 | tiksi
# No such city, skipping this one...
# Processing record 44 of Set 1 | kavaratti
# Processing record 45 of Set 1 | ushuaia
# Processing record 46 of Set 1 | herat
# Processing record 47 of Set 1 | zhangjiakou
# Processing record 48 of Set 1 | barrow
# Processing record 49 of Set 1 | itarema
# No such city, skipping this one...
# Processing record 50 of Set 1 | kununurra
# Processing record 1 of Set 2 | bluff
# Processing record 2 of Set 2 | vardo
# Processing record 3 of Set 2 | tasiilaq
# Processing record 4 of Set 2 | thabazimbi
# Processing record 5 of Set 2 | salym
# No such city, skipping this one...
# Processing record 6 of Set 2 | bredasdorp
# Processing record 7 of Set 2 | buala
# Processing record 8 of Set 2 | ixtapa
# Processing record 9 of Set 2 | mahebourg
# Processing record 10 of Set 2 | sao joao da barra
# Processing record 11 of Set 2 | cayenne
# Processing record 12 of Set 2 | hambantota
# Processing record 13 of Set 2 | moirang
# Processing record 14 of Set 2 | erenhot
# No such city, skipping this one...
# No such city, skipping this one...
# Processing record 15 of Set 2 | tiarei
# Processing record 16 of Set 2 | kamaishi
# Processing record 17 of Set 2 | syracuse
# Processing record 18 of Set 2 | kapoeta
# No such city, skipping this one...
# Processing record 19 of Set 2 | ponta do sol
# Processing record 20 of Set 2 | hasaki
# Processing record 21 of Set 2 | loa janan
# Processing record 22 of Set 2 | nador
# No such city, skipping this one...
# Processing record 23 of Set 2 | bethel
# Processing record 24 of Set 2 | bonavista
# Processing record 25 of Set 2 | shakawe
# Processing record 26 of Set 2 | thompson
# Processing record 27 of Set 2 | porto santo
# Processing record 28 of Set 2 | east london
# Processing record 29 of Set 2 | avarua
# Processing record 30 of Set 2 | belaya gora
# Processing record 31 of Set 2 | rikitea
# Processing record 32 of Set 2 | sitka
# Processing record 33 of Set 2 | new norfolk
# Processing record 34 of Set 2 | jamestown
# No such city, skipping this one...
# Processing record 35 of Set 2 | new glasgow
# Processing record 36 of Set 2 | vaini
# Processing record 37 of Set 2 | khatanga
# Processing record 38 of Set 2 | punta arenas
# Processing record 39 of Set 2 | arraial do cabo
# Processing record 40 of Set 2 | codrington
# Processing record 41 of Set 2 | alofi
# Processing record 42 of Set 2 | cidreira
# Processing record 43 of Set 2 | sulangan
# Processing record 44 of Set 2 | hualmay
# Processing record 45 of Set 2 | sola
# Processing record 46 of Set 2 | santa isabel
# Processing record 47 of Set 2 | kapaa
# Processing record 48 of Set 2 | acarau
# Processing record 49 of Set 2 | zapolyarnyy
# Processing record 50 of Set 2 | filadelfia
# No such city, skipping this one...
# Processing record 1 of Set 3 | buin
# Processing record 2 of Set 3 | dunedin
# Processing record 3 of Set 3 | kalabo
# Processing record 4 of Set 3 | mocuba
# Processing record 5 of Set 3 | puerto escondido
# Processing record 6 of Set 3 | tuktoyaktuk
# Processing record 7 of Set 3 | teknaf
# Processing record 8 of Set 3 | norman wells
# No such city, skipping this one...
# Processing record 9 of Set 3 | hami
# Processing record 10 of Set 3 | te anau
# Processing record 11 of Set 3 | alice springs
# Processing record 12 of Set 3 | shingu
# Processing record 13 of Set 3 | rantepao
# Processing record 14 of Set 3 | tura
# Processing record 15 of Set 3 | tigil
# Processing record 16 of Set 3 | simoes
# Processing record 17 of Set 3 | suraabad
# Processing record 18 of Set 3 | bocanda
# Processing record 19 of Set 3 | svetlogorsk
# No such city, skipping this one...
# Processing record 20 of Set 3 | manaure
# Processing record 21 of Set 3 | dingle
# Processing record 22 of Set 3 | tayzhina
# Processing record 23 of Set 3 | banjar
# Processing record 24 of Set 3 | ust-tsilma
# Processing record 25 of Set 3 | tilichiki
# Processing record 26 of Set 3 | castro
# Processing record 27 of Set 3 | qaanaaq
# Processing record 28 of Set 3 | ponta delgada
# Processing record 29 of Set 3 | georgetown
# Processing record 30 of Set 3 | saint-philippe
# Processing record 31 of Set 3 | salina
# Processing record 32 of Set 3 | paracuru
# No such city, skipping this one...
# Processing record 33 of Set 3 | beloha
# Processing record 34 of Set 3 | pervomayskoye
# Processing record 35 of Set 3 | motygino
# Processing record 36 of Set 3 | kodiak
# Processing record 37 of Set 3 | vao
# Processing record 38 of Set 3 | fortuna
# Processing record 39 of Set 3 | doha
# Processing record 40 of Set 3 | wagar
# Processing record 41 of Set 3 | santa cruz
# Processing record 42 of Set 3 | corning
# Processing record 43 of Set 3 | nhulunbuy
# Processing record 44 of Set 3 | chardara
# Processing record 45 of Set 3 | guerrero negro
# Processing record 46 of Set 3 | henties bay
# Processing record 47 of Set 3 | kathu
# Processing record 48 of Set 3 | dikson
# Processing record 49 of Set 3 | doaba
# Processing record 50 of Set 3 | surab
# Processing record 1 of Set 4 | ribeira grande
# Processing record 2 of Set 4 | airai
# Processing record 3 of Set 4 | brae
# Processing record 4 of Set 4 | yeniseysk
# Processing record 5 of Set 4 | kruisfontein
# Processing record 6 of Set 4 | kapit
# Processing record 7 of Set 4 | bajah
# Processing record 8 of Set 4 | raduzhnyy
# Processing record 9 of Set 4 | sorong
# Processing record 10 of Set 4 | atambua
# Processing record 11 of Set 4 | priargunsk
# Processing record 12 of Set 4 | macheng
# Processing record 13 of Set 4 | geraldton
# Processing record 14 of Set 4 | faanui
# Processing record 15 of Set 4 | nortelandia
# Processing record 16 of Set 4 | rio grande
# Processing record 17 of Set 4 | mercedes
# Processing record 18 of Set 4 | carnarvon
# Processing record 19 of Set 4 | micheweni
# Processing record 20 of Set 4 | rochester
# Processing record 21 of Set 4 | lorengau
# Processing record 22 of Set 4 | patawag
# Processing record 23 of Set 4 | namibe
# Processing record 24 of Set 4 | kutum
# Processing record 25 of Set 4 | fort-shevchenko
# Processing record 26 of Set 4 | halifax
# Processing record 27 of Set 4 | rawson
# Processing record 28 of Set 4 | sao manuel
# Processing record 29 of Set 4 | panguna
# Processing record 30 of Set 4 | lazaro cardenas
# Processing record 31 of Set 4 | jinji
# Processing record 32 of Set 4 | carayao
# Processing record 33 of Set 4 | chhagalnaiya
# Processing record 34 of Set 4 | anadyr
# Processing record 35 of Set 4 | conde
# Processing record 36 of Set 4 | nanortalik
# Processing record 37 of Set 4 | necochea
# Processing record 38 of Set 4 | longyearbyen
# Processing record 39 of Set 4 | ancud
# Processing record 40 of Set 4 | teguise
# Processing record 41 of Set 4 | port blair
# Processing record 42 of Set 4 | san cristobal
# Processing record 43 of Set 4 | abha
# No such city, skipping this one...
# Processing record 44 of Set 4 | iqaluit
# Processing record 45 of Set 4 | urucara
# Processing record 46 of Set 4 | buckingham
# Processing record 47 of Set 4 | port alfred
# Processing record 48 of Set 4 | korla
# Processing record 49 of Set 4 | rundu
# Processing record 50 of Set 4 | souillac
# Processing record 1 of Set 5 | las margaritas
# Processing record 2 of Set 5 | walvis bay
# Processing record 3 of Set 5 | ulladulla
# No such city, skipping this one...
# Processing record 4 of Set 5 | turan
# Processing record 5 of Set 5 | dali
# Processing record 6 of Set 5 | santa catarina de tepehuanes
# Processing record 7 of Set 5 | lavrentiya
# Processing record 8 of Set 5 | saldanha
# Processing record 9 of Set 5 | vichy
# Processing record 10 of Set 5 | yumen

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_lists = {
             "Cloudiness":clouds, 
             "Country":countries,
             "Humidity":humidity,
             "Latitude":lat,
             "Longitude":long,
             "Temperature (F)":temp,
             "Wind Speed":wind,
             "Date": date,
             "City": city_list,
}

weather_df = pd.DataFrame(weather_lists)
weather_df.to_csv('cities.csv', index = True, index_label = 'city_id')
weather_df
# Out:
#      Cloudiness Country  Humidity  Latitude  Longitude  Temperature (F)  \
# 0             1      US        25   44.7749  -117.8344            77.00
# 1             1      US        14   35.1981  -111.6513            66.20
# 2            40      CA        53   48.5501   -71.3324            51.01
# 3            90      US        46   34.6381   -99.3340            69.80
# 4             1      US        15   41.0002  -115.5012            77.00
# ..          ...     ...       ...       ...        ...              ...
# 709           1      US        18   47.6499  -117.2399            77.00
# 710         100      CA        34   49.6000  -114.4353            64.40
# 711           1      US        88   30.7621   -86.5705            73.40
# 712         100      US        88   40.4465   -74.3860            69.01
# 713           1      US        82   40.8665  -124.0828            57.00
#
#      Wind Speed        Date            City
# 0         16.11  1619747460      baker city
# 1          5.75  1619747461       flagstaff
# 2         12.66  1619747461  saint-ambroise
# 3         10.36  1619747461           altus
# 4          3.44  1619747462            elko
# ..          ...         ...             ...
# 709       10.36  1619747678     opportunity
# 710       10.36  1619747678       blairmore
# 711        4.61  1619747679       crestview
# 712        1.01  1619747679     south river
# 713        8.05  1619747680          arcata
#
# [714 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_df.describe()
# Out:
#        Cloudiness    Humidity    Latitude   Longitude  Temperature (F)  \
# count  714.000000  714.000000  714.000000  714.000000       714.000000
# mean    42.270308   56.690476   38.736266  -87.125159        65.854608
# std     41.812492   28.385263   10.954639   39.466806        12.399120
# min      0.000000    1.000000  -41.533300 -127.419900        32.000000
# 25%      1.000000   30.000000   34.740600 -108.564600        57.200000
# 50%     20.000000   59.000000   40.088200  -91.575900        66.990000
# 75%     90.000000   83.000000   44.477125  -81.018200        73.990000
# max    100.000000  100.000000   57.143700  173.283300        98.600000
#
#        Wind Speed          Date
# count  714.000000  7.140000e+02
# mean     8.159874  1.619747e+09
# std      4.506775  1.498562e+02
# min      0.920000  1.619747e+09
# 25%      4.610000  1.619747e+09
# 50%      7.000000  1.619748e+09
# 75%     11.500000  1.619748e+09
# max     27.630000  1.619748e+09

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
y_values = ['Temperature (F)', 'Humidity', 'Cloudiness', 'Wind Speed']
for y_axis in y_values:
    x = weather_df['Latitude']
    y = weather_df[y_axis]
    plt.scatter(x,y, edgecolor='black')
    plt.xlabel('Latitude')
    plt.ylabel(y_axis)
    plt.title('Latitude vs ' + y_axis + ' (%s) ' % time.strftime("%x"))
    plt.show(

# %% [markdown]
# ## Linear Regression

# %%
# Split between northern and southern hemisphere
north = weather_df.loc[(weather_df['Latitude']>0)]
south = weather_df.loc[(weather_df['Latitude']<0)]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Northern Hemisphere Regression Lines
y_values = ['Temperature (F)', 'Humidity', 'Cloudiness', 'Wind Speed']
for y_axis in y_values:
    x = north['Latitude']
    y = north[y_axis]
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x,y, edgecolor='black')
    plt.plot(x,regress_values,"r-")
    plt.xlabel('Latitude')
    plt.ylabel(y_axis)
    plt.title('Northern Hemisphere - ' + y_axis + ' vs. Latitude Linear Regression')
    print(f'Fit line eq: {line_eq2}')
    print(f'R-squared: {rvalue}')
    plt.show()
    
# Southern Hemisphere Regression Lines
for y_axis in y_values:
    x = south['Latitude']
    y = south[y_axis]
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq2 = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x,y, edgecolor = 'black')
    plt.plot(x,regress_values,"r-")
    plt.xlabel('Latitude')
    plt.ylabel(y_axis)
    plt.title('Southern Hemisphere - ' + y_axis + ' vs. Latitude Linear Regression')
    print(f'Fit line eq: {line_eq2}')
    print(f'R-squared: {rvalue}')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-d544d849b404> in <module>
#      13     plt.ylabel(y_axis)
#      14     plt.title('Northern Hemisphere - ' + y_axis + ' vs. Latitude Linear Regression')
# ---> 15     print(f'Fit line eq: {line_eq2}')
#      16     print(f'R-squared: {rvalue}')
#      17     plt.show()
#
# NameError: name 'line_eq2' is not defined
