# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import time
import json

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
output_data = "../output_data/cities.csv"

output_data_df = pd.read_csv(output_data).drop(columns=["City_ID"])

output_data_df
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      ostrovnoy           2      RU  1558378754        72  68.05   39.51
# 1      mahebourg          75      MU  1558378503        74 -20.41   57.70
# 2        qaanaaq          25      GL  1558378755        73  77.48  -69.36
# 3         zhuhai           0      CN  1558378755        39  40.71  112.04
# 4      cape town          20      ZA  1558378755        76 -33.93   18.42
# ..           ...         ...     ...         ...       ...    ...     ...
# 543       yabrud           0      SY  1558378840        32  33.97   36.66
# 544      paraiso           5      MX  1558378898         4  24.01 -104.61
# 545      veraval           0      FR  1558378898        62  49.65    0.71
# 546  novyy urgal         100      RU  1558378899        93  51.07  132.56
# 547      tongren           4      CN  1558378899        64  27.72  109.18
#
#      Max Temp  Wind Speed
# 0       37.50        7.16
# 1       78.80       11.41
# 2       22.20        2.37
# 3       44.60        4.47
# 4       55.99        8.05
# ..        ...         ...
# 543     80.60        8.05
# 544     84.20       16.11
# 545     61.00        8.05
# 546     49.74        2.68
# 547     55.86        2.84
#
# [548 rows x 9 columns]

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
gmaps.configure(api_key=g_key)

# %%
locations = output_data_df[["Lat", "Lng"]]
humidity = output_data_df["Humidity"]
maxhum = humidity.max()

# %%
fig = gmaps.figure(center=(12, 0), zoom_level=1.75)
heatmap_layer = gmaps.heatmap_layer(locations, weights=humidity, max_intensity = maxhum, dissipating=False, point_radius=3)
fig.add_layer(heatmap_layer)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.
# * Narrow down the DataFrame to find your ideal weather condition. For example:
#
#   * A max temperature lower than 80 degrees but higher than 70.
#
#   * Wind speed less than 10 mph.
#
#   * Zero cloudiness.
#
#   * Drop any rows that don't contain all three conditions. You want to be sure the weather is ideal.

# %%
best_fit_df = pd.DataFrame(output_data_df, columns = ["City", "Max Temp", "Wind Speed", "Cloudiness", "Country", "Lat", "Lng"])

temp_range = (best_fit_df["Max Temp"] <= 75) & (best_fit_df["Max Temp"] >65)
wind_speed = best_fit_df["Wind Speed"] <= 10
cloud_cover = best_fit_df["Cloudiness"] <= 15
country = best_fit_df["Country"] != "RU"
lat = best_fit_df["Lat"]
lng = best_fit_df["Lng"]

best_fit_df = best_fit_df[temp_range & wind_speed & cloud_cover & country]
best_fit_df
# Out:
#                  City  Max Temp  Wind Speed  Cloudiness Country    Lat     Lng
# 7               opuwo     72.06        5.44           0     NaN -18.06   13.84
# 30            gobabis     68.00        2.24           0     NaN -22.45   18.97
# 70       ponta do sol     73.68        5.32           0      BR -20.63  -46.00
# 87           ambilobe     74.76        4.52           2      MG -13.19   49.05
# 168          straumen     68.00        9.17           0      NO  63.87   11.30
# 214         mount isa     68.00        6.93           0      AU -20.73  139.49
# 231            mocuba     65.76        2.42           1      MZ -16.84   36.99
# 259              hami     69.72        6.20           0      CN  42.84   93.51
# 297             mogok     72.24        2.77           0      MM  22.92   96.51
# 338    port shepstone     69.54        5.32           2      ZA -30.74   30.45
# 346          chiredzi     65.76        0.78           0      ZW -21.05   31.67
# 402           sambava     70.98        1.50           7      MG -14.27   50.17
# 444           birjand     71.60        9.17           0      IR  32.86   59.22
# 533           hakkari     69.80        5.82           0      FI  61.34   23.75
# 538  la seyne-sur-mer     69.01        2.24           0      FR  43.10    5.88

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df = pd.DataFrame(best_fit_df, columns=["City", "Country", "Lat", "Lng"])
hotel_df["Hotel Name"] = ""
hotel_df.head()
# Out:
#              City Country    Lat    Lng Hotel Name
# 7           opuwo     NaN -18.06  13.84
# 30        gobabis     NaN -22.45  18.97
# 70   ponta do sol      BR -20.63 -46.00
# 87       ambilobe      MG -13.19  49.05
# 168      straumen      NO  63.87  11.30

# %%
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json?"

params = {"type" : "hotel",
          "keyword" : "hotel",
          "radius" : 5000,
          "key" : g_key}

for index, row in hotel_df.iterrows():
    lat = row["Lat"]
    lng = row["Lng"]
    city = row["City"]
    
    params["location"] = f"{lat},{lng}"
    
    print(f"Getting results for {city}.")
    response = requests.get(base_url, params=params).json()
    results = response['results']
    
    #Save the hotel name to the dataframe
    try:
        print(f"Closest hotel in {city} is {results[0]['name']}.")
        hotel_df.loc[index, "Hotel Name"] = results[0]['name']
    except (KeyError, IndexError):
        print("Could not find result")
        print("-------------------------")
        hotel_df.loc[index, "Hotel Name"] = "No hotels"
    #delay the code by one second to avoid an error
    time.sleep(1)
        
hotel_df
# Out:
# Getting results for opuwo.
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -18.0446824,
#                     "lng": 13.8335005
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -18.04348247010728,
#                         "lng": 13.83472832989272
#                     },
#                     "southwest": {
#                         "lat": -18.04618212989272,
#                         "lng": 13.83202867010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Opuwo Country Lodge",
#             "place_id": "ChIJySzHs8KTkBsRiQMc4YaV6hA",
#             "plus_code": {
#                 "compound_code": "XR4M+4C Opuwo, Namibia",
#                 "global_code": "5FHMXR4M+4C"
#             },
#             "rating": 4.2,
#             "reference": "ChIJySzHs8KTkBsRiQMc4YaV6hA",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 278,
#             "vicinity": "Opuwo"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -18.0591931,
#                     "lng": 13.8405505
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -18.05777972010728,
#                         "lng": 13.84192097989272
#                     },
#                     "southwest": {
#                         "lat": -18.06047937989272,
#                         "lng": 13.83922132010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Ohakane Guesthouse",
#             "place_id": "ChIJm2q4asmTkBsRODcAS7HS16E",
#             "plus_code": {
#                 "compound_code": "WRRR+86 Opuwo, Namibia",
#                 "global_code": "5FHMWRRR+86"
#             },
#             "rating": 3.7,
#             "reference": "ChIJm2q4asmTkBsRODcAS7HS16E",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 113,
#             "vicinity": "Opuwo"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -18.061001,
#                     "lng": 13.8382612
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -18.05971562010728,
#                         "lng": 13.83971067989272
#                     },
#                     "southwest": {
#                         "lat": -18.06241527989272,
#                         "lng": 13.83701102010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Uukwaluudhi Lodge",
#             "place_id": "ChIJ1xDSHMyTkBsR_GNxEuzZTIs",
#             "plus_code": {
#                 "compound_code": "WRQQ+H8 Opuwo, Namibia",
#                 "global_code": "5FHMWRQQ+H8"
#             },
#             "rating": 3.4,
#             "reference": "ChIJ1xDSHMyTkBsR_GNxEuzZTIs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 13,
#             "vicinity": "Opuwo"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -18.054129,
#                     "lng": 13.8438893
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -18.05264707010728,
#                         "lng": 13.84528062989272
#                     },
#                     "southwest": {
#                         "lat": -18.05534672989272,
#                         "lng": 13.84258097010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "ABBA Guesthouse",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "place_id": "ChIJa15j5MeTkBsRFpqaXwd1FXg",
#             "plus_code": {
#                 "compound_code": "WRWV+8H Opuwo, Namibia",
#                 "global_code": "5FHMWRWV+8H"
#             },
#             "rating": 3.8,
#             "reference": "ChIJa15j5MeTkBsRFpqaXwd1FXg",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 149,
#             "vicinity": "Muharukua Ave, Opuwo"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -18.0789127,
#                     "lng": 13.8847347
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -18.07820437010728,
#                         "lng": 13.88562152989273
#                     },
#                     "southwest": {
#                         "lat": -18.08090402989272,
#                         "lng": 13.88292187010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Kaoko Mopane Lodge & Campsite",
#             "place_id": "ChIJOUjRjtiTkBsR2661h2-V8FQ",
#             "plus_code": {
#                 "compound_code": "WVCM+CV Opuwo, Namibia",
#                 "global_code": "5FHMWVCM+CV"
#             },
#             "rating": 5,
#             "reference": "ChIJOUjRjtiTkBsR2661h2-V8FQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "Unnamed Road"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -18.0602282,
#                     "lng": 13.8425646
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -18.05873217010728,
#                         "lng": 13.84395362989272
#                     },
#                     "southwest": {
#                         "lat": -18.06143182989273,
#                         "lng": 13.84125397010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Aameny Rest Camp",
#             "place_id": "ChIJTxk3hsmTkBsRSHog_XZc79Q",
#             "plus_code": {
#                 "compound_code": "WRQV+W2 Opuwo, Namibia",
#                 "global_code": "5FHMWRQV+W2"
#             },
#             "rating": 3.6,
#             "reference": "ChIJTxk3hsmTkBsRSHog_XZc79Q",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 51,
#             "vicinity": "Opuwo"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -18.0537588,
#                     "lng": 13.8408558
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -18.05256447010728,
#                         "lng": 13.84214097989272
#                     },
#                     "southwest": {
#                         "lat": -18.05526412989272,
#                         "lng": 13.83944132010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "P Wake Guesthouse",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "place_id": "ChIJ4ZXzO8aTkBsRx40E_Z32Sak",
#             "plus_code": {
#                 "compound_code": "WRWR+F8 Opuwo, Namibia",
#                 "global_code": "5FHMWRWR+F8"
#             },
#             "rating": 3.2,
#             "reference": "ChIJ4ZXzO8aTkBsRx40E_Z32Sak",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 32,
#             "vicinity": "3334 Kleophas Tjijeura Street, Opuwo"
#         }
#     ],
#     "status": "OK"
# }
# Getting results for gobabis.
# {
#     "html_attributions": [],
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.4541248,
#                     "lng": 18.9772075
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.45280642010728,
#                         "lng": 18.97855882989272
#                     },
#                     "southwest": {
#                         "lat": -22.45550607989272,
#                         "lng": 18.97585917010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Onze Rust Guest House",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2268,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102657568108908750978\">Conrad Vermaak</a>"
#                     ],
#                     "photo_reference": "ATtYBwI63c6edTJQMJmrrLMZ33JYEm_RrVcPV2aenLRDsc_5kxBxBB_C_4-R_yMaKOLSUalTjjYR3nXq84Rsppdowb8c1o0JttZCJvPGPE31Lx9AEuSM23cawByI-YoqCGCrwHq7P3SSjNTcotJwB2Rb6AQvWgk4JhOCc-nV_fKWxbg4q8L4",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJubExoW3lCBwRVrYd_EYd9mc",
#             "plus_code": {
#                 "compound_code": "GXWG+9V Gobabis, Namibia",
#                 "global_code": "5F9WGXWG+9V"
#             },
#             "rating": 3.7,
#             "reference": "ChIJubExoW3lCBwRVrYd_EYd9mc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 74,
#             "vicinity": "Rugby, Gobabis"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.44858,
#                     "lng": 18.95593
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.44772592010728,
#                         "lng": 18.95790272989272
#                     },
#                     "southwest": {
#                         "lat": -22.45042557989272,
#                         "lng": 18.95520307010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Goba Lodge",
#             "photos": [
#                 {
#                     "height": 3840,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109927040347282959440\">Bella Le Roux</a>"
#                     ],
#                     "photo_reference": "ATtYBwKgyht4N6DWwj8UjfWqz0_vNRwOopVDR0sZPWqTiDdcFGncOieL0VVE5ZHB3srErki-HvKwf5WcDpkvZktTWoQuqtd-f91MHa2aGBQSvQtGDM8abiR9oUCt0irhtOj0AxmwY9Lvgl2BeefpHsylaIY1FjVTMFo8iyeYftvEEsVFSBJw",
#                     "width": 5120
#                 }
#             ],
#             "place_id": "ChIJ0UDmLx_lCBwRdsTHKgpHjkc",
#             "plus_code": {
#                 "compound_code": "HX24+H9 Gobabis, Namibia",
#                 "global_code": "5F9WHX24+H9"
#             },
#             "rating": 4.2,
#             "reference": "ChIJ0UDmLx_lCBwRdsTHKgpHjkc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 183,
#             "vicinity": "Gobabis"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.450687,
#                     "lng": 18.9941637
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.44937132010728,
#                         "lng": 18.99551432989272
#                     },
#                     "southwest": {
#                         "lat": -22.45207097989272,
#                         "lng": 18.99281467010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Steps Accommodation",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/109108884689814033324\">Peik Bruhns</a>"
#                     ],
#                     "photo_reference": "ATtYBwLSaWqurWkVSiYFz-zXFaz5cgi5NoKvSzn6f4UUO5VMXbKbMS2Tz_pSVHnBI3xjmdeAGunErDTYNVP3QqfzUBREJ9kID0Ioch1BldLiQxiR-sZsc8azDE42hVAVdxMM1DqxOYbeCjxb_PUt8K9GxlOX7rRG8GWpQGzFgRynb_iOMy0L",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJF84fl_7lCBwRg01zLZloiCU",
#             "plus_code": {
#                 "compound_code": "GXXV+PM Gobabis, Namibia",
#                 "global_code": "5F9WGXXV+PM"
#             },
#             "rating": 4.7,
#             "reference": "ChIJF84fl_7lCBwRg01zLZloiCU",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 11,
#             "vicinity": "Hermanus Landsberg Avenue, Gobabis"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.4457752,
#                     "lng": 18.9597493
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.44441872010728,
#                         "lng": 18.96133417989272
#                     },
#                     "southwest": {
#                         "lat": -22.44711837989272,
#                         "lng": 18.95863452010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "De Dam",
#             "place_id": "ChIJm2Os1M_lCBwR983wVpDifAs",
#             "plus_code": {
#                 "compound_code": "HX35+MV Gobabis, Namibia",
#                 "global_code": "5F9WHX35+MV"
#             },
#             "rating": 1,
#             "reference": "ChIJm2Os1M_lCBwR983wVpDifAs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Gobabis"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.4492792,
#                     "lng": 18.971192
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.44785382010728,
#                         "lng": 18.97253872989273
#                     },
#                     "southwest": {
#                         "lat": -22.45055347989273,
#                         "lng": 18.96983907010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Omara Guesthouse",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 5312,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111977703932127254164\">Alon Cohen-Lifshitz</a>"
#                     ],
#                     "photo_reference": "ATtYBwJzaH2XZVgzHTEAMVpgTfbS9ImK5MUfT0s8y5SJBKYgEMJrzgeY60YjaspCGv1DwbePWiPbj3_G1Ta2cd-mmO_vsy87cymvMvUnHEz_BVj0iqFZWFkzyTjVXKda200W8KPV1P0QtoP_9ZlG1L0YkO8ymZOFyoi01x69enQ_eA7iM7pN",
#                     "width": 2988
#                 }
#             ],
#             "place_id": "ChIJo6IA9RTlCBwRGxcHzEIWGB4",
#             "plus_code": {
#                 "compound_code": "HX2C+7F Gobabis, Namibia",
#                 "global_code": "5F9WHX2C+7F"
#             },
#             "rating": 3.8,
#             "reference": "ChIJo6IA9RTlCBwRGxcHzEIWGB4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 13,
#             "vicinity": "Kalahari Street, Gobabis"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.4545987,
#                     "lng": 18.9841316
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.45324092010728,
#                         "lng": 18.98553402989272
#                     },
#                     "southwest": {
#                         "lat": -22.45594057989272,
#                         "lng": 18.98283437010727
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Uakii Eco Guesthouse",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 1960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117353971913309365046\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwIfvxknL7Ov9J2fVhUE_32XnpT0pIrO3GaAv1Y2AdS2W8PxaSTlZgMxB8xVY9r5b8SC_czOmbkzTv_mDhBh9L78JxdCGH7RwgfAcHKWi4d6uAtOEtjlq3o_VqHpUCMbYE7OOY10uw0qf4O37vXQezaZvGAFrduqZk-OnDdPZW2GkYhe",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJt4wh3G_lCBwRkVTTWp7Fi6M",
#             "plus_code": {
#                 "compound_code": "GXWM+5M Gobabis, Namibia",
#                 "global_code": "5F9WGXWM+5M"
#             },
#             "rating": 3.8,
#             "reference": "ChIJt4wh3G_lCBwRkVTTWp7Fi6M",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 22,
#             "vicinity": "Erf. 1053, Van Der Zaag Street, Smalligerland,, Gobabis"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.4458034,
#                     "lng": 18.959751
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.44444697010727,
#                         "lng": 18.96133547989272
#                     },
#                     "southwest": {
#                         "lat": -22.44714662989272,
#                         "lng": 18.95863582010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Die Dam Trans Kalahari End Resort",
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102959468294908497776\">Niklaus Imboden</a>"
#                     ],
#                     "photo_reference": "ATtYBwLwJOzox0anhXsz_sh6xQ6_t50oGiwU2oJ1F6DHJOTHITdfKjUYwM6LY0moxq36_HxFIwy5rEKFqoVJ6Lf8nLEWO8pLDWlJjSG4OaO0qJo8oNY4f1lx_jzGfifCwt7cCrivGjyX5Z89kv-VWnODWxmixbDdcKj08xL9r4z7-MY_wvZ9",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJDeG__oPlCBwRspkfRg8uJDw",
#             "plus_code": {
#                 "compound_code": "HX35+MW Gobabis, Namibia",
#                 "global_code": "5F9WHX35+MW"
#             },
#             "rating": 4.1,
#             "reference": "ChIJDeG__oPlCBwRspkfRg8uJDw",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 114,
#             "vicinity": "Gobabis"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.4530503,
#                     "lng": 18.9684256
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.45170152010728,
#                         "lng": 18.96976462989272
#                     },
#                     "southwest": {
#                         "lat": -22.45440117989272,
#                         "lng": 18.96706497010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Die Windpomp Gastehuis",
#             "photos": [
#                 {
#                     "height": 2340,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111977881586336234083\">naveen</a>"
#                     ],
#                     "photo_reference": "ATtYBwLoEt3yHgLSmiSDz3qCNKbKkB3o-XqcfFYLNdkv8o9vgDzl7p87_Gott_mmRe9Ba4NecjDYWCAJ0-l22r6SQDXgVgSROGOMzBJHewk8pxB-hQMY_xRKS2pMpBJ7Pz9hXLy9a36xR-3CWWcUnCxuyCB85kJE6KKr9Oc4c4SaevyGEMhV",
#                     "width": 4160
#                 }
#             ],
#             "place_id": "ChIJHWf92xPlCBwRbhMVu2yAS0o",
#             "plus_code": {
#                 "compound_code": "GXW9+Q9 Gobabis, Namibia",
#                 "global_code": "5F9WGXW9+Q9"
#             },
#             "rating": 4.5,
#             "reference": "ChIJHWf92xPlCBwRbhMVu2yAS0o",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 82,
#             "vicinity": "C20, Gobabis"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -22.4500056,
#                     "lng": 18.9679096
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -22.44868907010727,
#                         "lng": 18.96913952989272
#                     },
#                     "southwest": {
#                         "lat": -22.45138872989272,
#                         "lng": 18.96643987010728
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#             "name": "Ernis Bistro",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 4160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115275402110317816666\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwJzlSzCwCxAHOu3mziELsPetr-pHEHykZs6Q0Y-9wgbtgBYiqUdaJ0oZGrZ2N5krlLfzZn8gVVP7Qdtp9ZcwYWjjJfHenOLqVgX3vegyd2BuAj0-YU4eSKwD7ohgG-zntSAH3ofoUbfZ6X0FlZflK4V_YEZrCthIquK1xow9KPGPjnB",
#                     "width": 3120
#                 }
#             ],
#             "place_id": "ChIJ57xQoBblCBwRR6bw8Ia_iyA",
#             "plus_code": {
#                 "compound_code": "GXX9+X5 Gobabis, Namibia",
#                 "global_code": "5F9WGXX9+X5"
#             },
#             "price_level": 2,
#             "rating": 3.3,
#             "reference": "ChIJ57xQoBblCBwRR6bw8Ia_iyA",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 131,
#             "vicinity": "Gobabis"
#         }
#     ],
#     "status": "OK"
# }
# Getting results for ponta do sol.
# {
#     "html_attributions": [],
#     "next_page_token": "ATtYBwJ4m_Dp-_Uc2zpLGjMN5JUFTcQs-Mtl1JUmfPLfQgQ1zAf2YiiTtXsYp8zppYXm9gG0yHAhqI0ADYd1BH2t93Bxw6kHrAbU9p2KEG1IvKrocwMJkUkmS-MmOlN-gQm5TFY3hHsUvrjdq1yCOSFjZe_D5PplmubtGVxjaTboJehkIy6gJ9wgkRiqir8UFMZpkYS0XQcn7Y_eDeG75n_SE6iNDvHZE7pLHrZ7NRMlWeg1H2mWsgRX3LX0EKwaljFlEN8Pooqh_aW_e7Zp5dHUDX_QEkmcVj1NuN9E-5023hB_E89jND8lzc2N1zIWiyRqRCBpf0S0V7xOPja3HTuRsqAcBNMbHphalbwyUbGCaHlV_p0nr-Vq8gG-2YgKpqLM5XDgFeenraNEGT5MmIoZo0FudgkGgkFEonYGaku0MLkGW3XNESzJizrU0jo-SKc",
#     "results": [
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6293335,
#                     "lng": -46.0286838
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.62803272010728,
#                         "lng": -46.02740152010728
#                     },
#                     "southwest": {
#                         "lat": -20.63073237989272,
#                         "lng": -46.03010117989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Escarpas Resort",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/111319234340209745470\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwIX8K6JxDNgZhgtHfUIypGERTqYuv9xH18JmvrUTpMszc26sXuIDzmiSFNE8bNscs0hBI8PpchB3uvbMa-S07ZYsU9J66Zupkyh8vdKHWt-0jAh1lKqb40084ClIC8k02XfFfvyV8Wfyf03ofmLmWVNBs53Knn5WIT0y5e9YXKPUaR1",
#                     "width": 3000
#                 }
#             ],
#             "place_id": "ChIJb1bFCO48tJQR6Nw2j-8BALQ",
#             "plus_code": {
#                 "compound_code": "9XCC+7G Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9XCC+7G"
#             },
#             "rating": 4.7,
#             "reference": "ChIJb1bFCO48tJQR6Nw2j-8BALQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 596,
#             "vicinity": "Av. Jose de Oliveira Ramos, 1505 - Centro, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6331634,
#                     "lng": -46.0303382
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.63195277010728,
#                         "lng": -46.02908047010727
#                     },
#                     "southwest": {
#                         "lat": -20.63465242989272,
#                         "lng": -46.03178012989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Kanto Island Inn Suites & Spa",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2848,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103273964572684594071\">Pousada Kanto da Ilha Suites &amp; Spa</a>"
#                     ],
#                     "photo_reference": "ATtYBwJ5U4IvEZFLs72mWz8H4xGVRsHbUWeosTEUbOBZBbY1XP7lW2PD_-aW5PdAF2Q_uBZ-Ka_rqHceSkL_OO5i3lzOaPuxPDly9LgOfh_pUOgzC4ZCzcnofEk_HoFWWx5znOqplo507Uhke362AjwGFE9Ok-KMLYjC2DCw3tqWOSC4yHpj",
#                     "width": 4288
#                 }
#             ],
#             "place_id": "ChIJm_NL--w8tJQR8vHCUJO_GGs",
#             "plus_code": {
#                 "compound_code": "9X89+PV Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9X89+PV"
#             },
#             "rating": 4.7,
#             "reference": "ChIJm_NL--w8tJQR8vHCUJO_GGs",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 324,
#             "vicinity": "R. Vicente Paulo Ramos - \u00c1guas das Vertentes, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6425523,
#                     "lng": -46.00563959999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.64119272010728,
#                         "lng": -46.00434157010727
#                     },
#                     "southwest": {
#                         "lat": -20.64389237989272,
#                         "lng": -46.00704122989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pousada Su\u00edtes do Lago",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 512,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103028673385193490244\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwLwiENBxCBC9nw9882LBru2zUjgsUlfhKrx6ONZSHbpsZkTJRfaRsrjC5WsZYnwamG05R5iHiNcFYlfbS0p7z_hRJcxbpGGZk1AsDuqgBKlpQ2kFJNBK-70Zh2Ajx6ZRgBFveCHypVxeqsWaQNmTzsoAcC_Br2iYVA3TA0fUJMTZOoC",
#                     "width": 812
#                 }
#             ],
#             "place_id": "ChIJISPGczw9tJQR2xLBO9BKTJQ",
#             "plus_code": {
#                 "compound_code": "9X4V+XP Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9X4V+XP"
#             },
#             "rating": 4.5,
#             "reference": "ChIJISPGczw9tJQR2xLBO9BKTJQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 45,
#             "vicinity": "R. dos Remos, 432, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6150112,
#                     "lng": -46.0501009
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.61365167010728,
#                         "lng": -46.04885212010728
#                     },
#                     "southwest": {
#                         "lat": -20.61635132989272,
#                         "lng": -46.05155177989273
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Capit\u00f3lio",
#             "photos": [
#                 {
#                     "height": 1194,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/108644244497847146568\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwL5P3uDDV4vpGMxMuSpZ25p0vv0s6La8sG2DEIEhRHqJMEz24GjcimlYUViN32JsijmOfLCL55T12sr2N7IYj-APhtW2vfCMzRr3oDVZI6nIhZ7VsNjmONnlKiusUloV41--i20bHuS8a_sy5S6yxy8esMDk3W_qVQR6JABjJnzdADp",
#                     "width": 1080
#                 }
#             ],
#             "place_id": "ChIJJYUYXS49tJQRtrA_mhLAwyM",
#             "plus_code": {
#                 "compound_code": "9WMX+XX Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9WMX+XX"
#             },
#             "rating": 3.6,
#             "reference": "ChIJJYUYXS49tJQRtrA_mhLAwyM",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 80,
#             "vicinity": "R. Passos Maia, 121 - Centro, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6183873,
#                     "lng": -46.0491482
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.61700662010728,
#                         "lng": -46.04779677010728
#                     },
#                     "southwest": {
#                         "lat": -20.61970627989272,
#                         "lng": -46.05049642989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pousada Buena Vista",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2940,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113385812944770937976\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwKlmPQAbleXfZlgVb4JTK3-sn_fL-R6PBOGgt4yvBvPRRlJAbku1K9Y9Y1nnLa9WTQXL2eyM7LjXZY1vFT_6vzqRBiHZQR2LczVnzw-WU2LZ_FSpRZ6biyGC2QCQmbMMISxr-AAQ_C_DKbzoGhCYwkkizshHzefolVrirbeBDYv6GH_",
#                     "width": 3920
#                 }
#             ],
#             "place_id": "ChIJ4czP7WA9tJQRTwhKsMUiDnw",
#             "plus_code": {
#                 "compound_code": "9XJ2+J8 Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9XJ2+J8"
#             },
#             "rating": 4.7,
#             "reference": "ChIJ4czP7WA9tJQRTwhKsMUiDnw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 99,
#             "vicinity": "R. Jos\u00e9 Pedro Ratis, 420 - Bela vista, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.631539,
#                     "lng": -46.0327344
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.63012367010728,
#                         "lng": -46.03135172010728
#                     },
#                     "southwest": {
#                         "lat": -20.63282332989272,
#                         "lng": -46.03405137989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pousada do Batata",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3024,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/118015720460896287737\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwJqjoktXL2vGx5mBPj7shoFXZWKvYdiylab2DqSHtCkHdt3U9lbEitCjT6gogZH5Es70_45EqvwdDXQ2hb5-xudoE0AMX1aIFBsJyPFhvk3VKk_oRcgjLLL6yiDoaea0wv-Vl2aobm32U5wVSz_EdAY29Wc_t6BLVBfEV9h0zWteiBw",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJW6WoFP49tJQRdPEj3L37cBo",
#             "plus_code": {
#                 "compound_code": "9X98+9W Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9X98+9W"
#             },
#             "rating": 4.9,
#             "reference": "ChIJW6WoFP49tJQRdPEj3L37cBo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 42,
#             "vicinity": "R. Clotilde Hort\u00eancio Ramos, 440, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6550091,
#                     "lng": -46.01224260000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.65370272010728,
#                         "lng": -46.01089992010728
#                     },
#                     "southwest": {
#                         "lat": -20.65640237989272,
#                         "lng": -46.01359957989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Camaleao Hostel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 536,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107302782508479813524\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwJzezOzE9VHJBHmaKl15b8DvuQgepFGrdbbruQTCV435gUCfwZkf_7cENxcC7IIT2vqhlHsGKhLvcHx7_JVkovBl0uiMxg-VNpTay1vaev7wRuTjusfGgUmEvpvzl1xpy9DxhFhQLYboYU2pkqvmDToCe7pVo1_yXEacUyjsIb1SFuz",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJEwZ2X4Q7tJQRuPg2b12dDUo",
#             "plus_code": {
#                 "compound_code": "8XVQ+X4 Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM8XVQ+X4"
#             },
#             "rating": 4.7,
#             "reference": "ChIJEwZ2X4Q7tJQRuPg2b12dDUo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 108,
#             "vicinity": "Condominio Escarpas do Lago - R. das Balsas, 220 - Escarpas do Lago, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6456114,
#                     "lng": -46.0097467
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.64429397010727,
#                         "lng": -46.00845397010728
#                     },
#                     "southwest": {
#                         "lat": -20.64699362989272,
#                         "lng": -46.01115362989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Hotel Escarpas do Lago",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102771479077732161127\">Escarpas Turismo</a>"
#                     ],
#                     "photo_reference": "ATtYBwJt07Oz_b07_VkJUMOP2ZUeZ7SUH44yuPap9pOZf-x7js1XtLX1v8Va_iVQR4BlSwr_cQ6RfAxmw1oeNFfD4Cf3EfcqpjFR7zPfgWOWSFIH33HwbSX4SB91sxr0ekgyOUr4M1vfusP4HeJ5dKs2FNpo_qmFY_9AxGXHcG_n-XP5G2yu",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJx8uifYE7tJQRf98euuRPbR4",
#             "plus_code": {
#                 "compound_code": "9X3R+Q4 Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9X3R+Q4"
#             },
#             "rating": 4.1,
#             "reference": "ChIJx8uifYE7tJQRf98euuRPbR4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 949,
#             "vicinity": "Avenida das Caravelas, Engenheiro Jos\u00e9 Mendes J\u00fanior, 25 - Escarpas do Lago, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.644364,
#                     "lng": -46.0106483
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.64301412010728,
#                         "lng": -46.00929837010727
#                     },
#                     "southwest": {
#                         "lat": -20.64571377989272,
#                         "lng": -46.01199802989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Escarpas Jatob\u00e1 Hotel",
#             "photos": [
#                 {
#                     "height": 1746,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116628278547020073106\">Sidney Lopes</a>"
#                     ],
#                     "photo_reference": "ATtYBwLnJ26gWI6P1S9x_8i8WFD0Xy2d2MqDOIW2X4Jcsok3JBnHAok84DBsABNhEqNitIIFAY0hMs5-UstNX8hiCwOMS27678MvPbDiSz-tGiB_bQ50gm43v5-hwlpz-As0_U2qdJAbCPXi1Z41Kdly_TOnRZmdzbtpWTVC2wnTbum7a7sn",
#                     "width": 3104
#                 }
#             ],
#             "place_id": "ChIJlzvbyHk8tJQRY79aHqQZaO4",
#             "plus_code": {
#                 "compound_code": "9X4Q+7P Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9X4Q+7P"
#             },
#             "rating": 4.4,
#             "reference": "ChIJlzvbyHk8tJQRY79aHqQZaO4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 141,
#             "vicinity": "Pra\u00e7a Dr. Marcos Valle Mendes, 46, Capit\u00f3lio 37930-000, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6324093,
#                     "lng": -46.0304527
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.63103112010728,
#                         "lng": -46.02908822010727
#                     },
#                     "southwest": {
#                         "lat": -20.63373077989272,
#                         "lng": -46.03178787989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pousada Viver Capit\u00f3lio",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4032,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113919254406709850131\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwK-pZAnscts_lfoVvnnKrhsBc_5dmN7t8MQfDmFQvH8IxXb0hxoGsmMwVDVyx2vGTbXDWC0UIeZOVtMuiEl30Zvy7qp11voFRjAUv2VHE0QOODa1U3RIXEZshuFVWoBqtmy9rg55jrW2BArXCr-WOzoTGZsjmpC-omQzP3a-K39qtX2",
#                     "width": 3024
#                 }
#             ],
#             "place_id": "ChIJA7HJmTk9tJQRpxuqhiLzlGE",
#             "plus_code": {
#                 "compound_code": "9X99+2R Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9X99+2R"
#             },
#             "rating": 4.7,
#             "reference": "ChIJA7HJmTk9tJQRpxuqhiLzlGE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 66,
#             "vicinity": "R. Clotilde Hort\u00eancio Ramos, 565 - \u00c1guas das Vertentes, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.6321792,
#                     "lng": -46.0309289
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": -20.63080997010728,
#                         "lng": -46.02956862010728
#                     },
#                     "southwest": {
#                         "lat": -20.63350962989272,
#                         "lng": -46.03226827989272
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Pousada Para\u00edso Mineiro",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2268,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101161512370594004677\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwK7BZRHou12PBnq8xAqiyEnDrAiLnE_pzfoPCWf_ogvgl-KNS4MzJKrTXPCnJ46YHEL16_whjvvdUjvoGImljpbEY6T0aq1bIW3hrC8rW_4jZRNr3bHLXIYwvk1-kixIAdP5lGusUJIdL5VpvF1_TgaspOoFeOfVkbpj1U-_fg2pRyN",
#                     "width": 4032
#                 }
#             ],
#             "place_id": "ChIJoy6ixdY9tJQR9oZGzDiQyzQ",
#             "plus_code": {
#                 "compound_code": "9X99+4J Capit\u00f3lio, State of Minas Gerais, Brazil",
#                 "global_code": "58FM9X99+4J"
#             },
#             "rating": 4.7,
#             "reference": "ChIJoy6ixdY9tJQR9oZGzDiQyzQ",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 64,
#             "vicinity": "R. Clotilde Hort\u00eancio Ramos, 440 - \u00c1gua das Vertente, Capit\u00f3lio"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": -20.618983,
# ...
#                     ],
#                     "photo_reference": "ATtYBwIgEQlSPwOUJKGy1m4l5RAth78QIglRIe6i87ywaN4AxPLuCV-_iKIVfpliMIYhkCU77ROZ4SsENm-swOOyljCW9nSFkMdMRS9c9XaUz2WxLWXhcNAqIB47KWQBF5rNg0HYs1bDZY5QEJbLQZoygazaWJ2_Io2fRJ8A4zGIJkNb79Kr",
#                     "width": 4000
#                 }
#             ],
#             "place_id": "ChIJ05lNNeoEyRIR1j80UVO8naY",
#             "plus_code": {
#                 "compound_code": "4VFF+9M Ollioules, France",
#                 "global_code": "8FM74VFF+9M"
#             },
#             "rating": 3.7,
#             "reference": "ChIJ05lNNeoEyRIR1j80UVO8naY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 747,
#             "vicinity": "554 Chemin de la Bouy\u00e8re, Ollioules"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.12676,
#                     "lng": 5.929761200000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.12800827989272,
#                         "lng": 5.931076679892722
#                     },
#                     "southwest": {
#                         "lat": 43.12530862010728,
#                         "lng": 5.928377020107278
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "OKKO Hotels Toulon Centre",
#             "photos": [
#                 {
#                     "height": 4000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/100817964142988236953\">Andy Panyanouvath</a>"
#                     ],
#                     "photo_reference": "ATtYBwJeAAXYhDH1JDiOSyLTiJL1wPfqZxNRDSRYwvMaUZCHPxX_I7_v0lPxxVN7weIBKiDlFUTOCLk632dPw_IcCi1rCc0losI1pKvhG8otojJtK4sKv9sDwalUn6Cf_t8IBnFPUY9TNogXFT3TSxpWgKZmTLVU8D9m-jrfbdxqWm6-6rs2",
#                     "width": 3000
#                 }
#             ],
#             "place_id": "ChIJ9R50VpgbyRIRefHr6Znwn3o",
#             "plus_code": {
#                 "compound_code": "4WGH+PW Toulon, France",
#                 "global_code": "8FM74WGH+PW"
#             },
#             "rating": 4.7,
#             "reference": "ChIJ9R50VpgbyRIRefHr6Znwn3o",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 82,
#             "vicinity": "20 Rue Peiresc, Toulon"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.1209474,
#                     "lng": 5.8485492
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.12238437989271,
#                         "lng": 5.849811029892721
#                     },
#                     "southwest": {
#                         "lat": 43.11968472010727,
#                         "lng": 5.847111370107277
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "H\u00f4tel Restaurant Campanile Toulon Six Fours",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 899,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115099140835670412288\">H\u00f4tel Restaurant Campanile Toulon - La Seyne sur mer - Sanary</a>"
#                     ],
#                     "photo_reference": "ATtYBwJR0Y71kWgl4V0LxQr5ljlBmY7kr03cgaFaHE6JytQNSyDsM4Y7m0RVqF1EShR39Bnm_wRcVOSu8xu9ati57701ighTgJfFfc3VCyb1aqpq7h2ZlHeFSEcLLxdecBT1dS0Ztr20AO2MsIaH0PigedxqEwMEyMKxiNzgSanmow8L9ImJ",
#                     "width": 1348
#                 }
#             ],
#             "place_id": "ChIJHRw4kGcEyRIRh2qsyjJURqI",
#             "plus_code": {
#                 "compound_code": "4RCX+9C Six-Fours-les-Plages, France",
#                 "global_code": "8FM74RCX+9C"
#             },
#             "rating": 3.7,
#             "reference": "ChIJHRw4kGcEyRIRh2qsyjJURqI",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 417,
#             "vicinity": "Chemin de la Capellane Lieu dit, Chemin de Bassaquet, Six-Fours-les-Plages"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.1223372,
#                     "lng": 5.929427599999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.12368172989273,
#                         "lng": 5.930770979892722
#                     },
#                     "southwest": {
#                         "lat": 43.12098207010729,
#                         "lng": 5.928071320107278
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "L' Eautel Toulon Port",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3988,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114256720718487762726\">A Google User</a>"
#                     ],
#                     "photo_reference": "ATtYBwIR4iVWQmwDSiKu6vI_OfXvXC0SMvSnyMWnoPXYMEYleDjrM1DvI5mj8W_vB2odVY_l4pZ1DbddYaa1IX0RKi1c5GKsNIzylAs6GMhm-QJLVFkA_CrYbguriAivrS8o0sMbuSPdGqLgZEDoCxGMTW36ylN3RJwyett7iEidEqrd-K9e",
#                     "width": 6948
#                 }
#             ],
#             "place_id": "ChIJAd1Qve4byRIRlBaFZcV2St4",
#             "plus_code": {
#                 "compound_code": "4WCH+WQ Toulon, France",
#                 "global_code": "8FM74WCH+WQ"
#             },
#             "rating": 4.7,
#             "reference": "ChIJAd1Qve4byRIRlBaFZcV2St4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 18,
#             "vicinity": "15 Rue Victor Micholet, Toulon"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.1069286,
#                     "lng": 5.8503856
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.10828732989272,
#                         "lng": 5.851805529892723
#                     },
#                     "southwest": {
#                         "lat": 43.10558767010728,
#                         "lng": 5.849105870107278
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "H\u00f4tel Premi\u00e8re Classe Toulon La Seyne Sur Mer",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 531,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102685286347578502024\">H\u00f4tel Premi\u00e8re Classe Toulon - La Seyne Sur Mer</a>"
#                     ],
#                     "photo_reference": "ATtYBwJe8E9f_RWZTw2imKnaU4z7EFp2c23TTeKe3PqTHCErojlR2kq2TW_v56jrREKu8DiWIRYjwxLXzxNNFzJeZMoNlhjzvvXwxM5qssL63dQzSDLnmG3mVd4p43gitKXwLhfPKnmIBs0fXyTm1_LoNpXkkBOEghyF-35hr9-MfesaEOmf",
#                     "width": 1200
#                 }
#             ],
#             "place_id": "ChIJEZ1dRXkEyRIRv53HJD4AblY",
#             "plus_code": {
#                 "compound_code": "4V42+Q5 La Seyne-sur-Mer, France",
#                 "global_code": "8FM74V42+Q5"
#             },
#             "rating": 3.1,
#             "reference": "ChIJEZ1dRXkEyRIRv53HJD4AblY",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 462,
#             "vicinity": "ZA Les Playes - Parc J.Monnet, 225 Avenue de Rome, La Seyne-sur-Mer"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.126502,
#                     "lng": 5.9316226
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.12790817989273,
#                         "lng": 5.933017329892722
#                     },
#                     "southwest": {
#                         "lat": 43.12520852010728,
#                         "lng": 5.930317670107278
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Celenya H\u00f4tel",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3669,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105884759572242780968\">Celenya H\u00f4tel</a>"
#                     ],
#                     "photo_reference": "ATtYBwLM7xre5C2yHv288TWHQbHtQFiwCi_pZ-5od5BHPchyEK0WnHXotI0-SJZVP5UEKnbC8EoYsGD3N_k33uJAWWv92HNsRdkDoCIcK3c-mwT78c79nKsqG2kwaP0BJ4Sms7dP6XZgtYVgb69ba88s3uZ7AbpYOShuIB_ZAwrqX0QkuUVV",
#                     "width": 5504
#                 }
#             ],
#             "place_id": "ChIJS2nq6g8byRIRPOwvF18kPUw",
#             "plus_code": {
#                 "compound_code": "4WGJ+JJ Toulon, France",
#                 "global_code": "8FM74WGJ+JJ"
#             },
#             "rating": 3.5,
#             "reference": "ChIJS2nq6g8byRIRPOwvF18kPUw",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 231,
#             "vicinity": "7 bisrue de Chabannes, Toulon"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.1153548,
#                     "lng": 5.8556629
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.11676257989271,
#                         "lng": 5.856618479892721
#                     },
#                     "southwest": {
#                         "lat": 43.11406292010727,
#                         "lng": 5.853918820107277
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "B&B HOTEL",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2667,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/113202586320797377247\">B&amp;B H\u00f4tel Toulon La Seyne Sur Mer</a>"
#                     ],
#                     "photo_reference": "ATtYBwK9V3cTSV-SITyPjaGSka_9j5lEXNtJA2m4q2MEVty3d755gUZMiEimHHY_oX-M3rVUBid72cdcilY6aVj1YJIIirXKy8VAJRknoLMDYn7y5YJUsNtWhsgnl_ZHIjhYwia4HWHyEfvzRvq2XDTFBMwMzN_CFA1QkKlq7Yzw_RybNmEL",
#                     "width": 4000
#                 }
#             ],
#             "place_id": "ChIJAyZja2MEyRIRkysZ803gz3o",
#             "plus_code": {
#                 "compound_code": "4V84+47 La Seyne-sur-Mer, France",
#                 "global_code": "8FM74V84+47"
#             },
#             "rating": 3.4,
#             "reference": "ChIJAyZja2MEyRIRkysZ803gz3o",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 781,
#             "vicinity": "167 Boulevard de l'Europe, La Seyne-sur-Mer"
#         },
#         {
#             "business_status": "OPERATIONAL",
#             "geometry": {
#                 "location": {
#                     "lat": 43.0723209,
#                     "lng": 5.9318276
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 43.07358332989272,
#                         "lng": 5.933208829892722
#                     },
#                     "southwest": {
#                         "lat": 43.07088367010728,
#                         "lng": 5.930509170107278
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png",
#             "name": "Les Bruyeres",
#             "photos": [
#                 {
#                     "height": 1536,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/112350758161439188537\">ber mahe</a>"
#                     ],
#                     "photo_reference": "ATtYBwK_SY1eMTR-egBOwAR3ap3UzurAbz42lyRbStUzzYsCS1PLtA5BXZvPcSIaR-S8dWeBJKgSbMYozD65dxb980Zp_lPqkDPgNdMKOjtBd7utuOdtrs2Z2dxx3JEkDZwZ2XXvkVlXnSBgTWXctCufRQDd3VyhrneH8EVHlFxKyYr5hPNt",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJyWHDtfEcyRIRjhPmDmcojD0",
#             "plus_code": {
#                 "compound_code": "3WCJ+WP Saint-Mandrier-sur-Mer, France",
#                 "global_code": "8FM73WCJ+WP"
#             },
#             "rating": 5,
#             "reference": "ChIJyWHDtfEcyRIRjhPmDmcojD0",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 10,
#             "vicinity": "21 Avenue de la Corniche d'Or, Saint-Mandrier-sur-Mer"
#         }
#     ],
#     "status": "OK"
# }
#                  City Country    Lat     Lng  \
# 7               opuwo     NaN -18.06   13.84
# 30            gobabis     NaN -22.45   18.97
# 70       ponta do sol      BR -20.63  -46.00
# 87           ambilobe      MG -13.19   49.05
# 168          straumen      NO  63.87   11.30
# 214         mount isa      AU -20.73  139.49
# 231            mocuba      MZ -16.84   36.99
# 259              hami      CN  42.84   93.51
# 297             mogok      MM  22.92   96.51
# 338    port shepstone      ZA -30.74   30.45
# 346          chiredzi      ZW -21.05   31.67
# 402           sambava      MG -14.27   50.17
# 444           birjand      IR  32.86   59.22
# 533           hakkari      FI  61.34   23.75
# 538  la seyne-sur-mer      FR  43.10    5.88
#
#                               Hotel Name
# 7                    Opuwo Country Lodge
# 30                 Onze Rust Guest House
# 70                       Escarpas Resort
# 87                        Hotel National
# 168               Jægtvolden Fjordhotell
# 214                            Isa Hotel
# 231                         Sumeia Hotel
# 259                           Hami Hotel
# 297                     MOGOK HILL HOTEL
# 338          Umthunzi Hotel & Conference
# 346                     The Nesbitt Arms
# 402                     Hôtel Las Palmas
# 444                            هتل پرويز
# 533                            No hotels
# 538  Best Western Plus Hôtel La Corniche

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
markers = gmaps.marker_layer(locations, info_box_content = hotel_info)
fig.add_layer(markers)
# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
